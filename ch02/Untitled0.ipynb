# %%
import numpy as npimport pandas as pdprint 'Hello world!'
# Out:
# Hello world!

# %%
tips = pd.read_csv(r'C:\Users\zyy\Downloads\pydata-book-master\ch08\tips.csv')tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size0       16.99  1.01  Female     No  Sun  Dinner     21       10.34  1.66    Male     No  Sun  Dinner     32       21.01  3.50    Male     No  Sun  Dinner     33       23.68  3.31    Male     No  Sun  Dinner     24       24.59  3.61  Female     No  Sun  Dinner     4

# %%
img = plt.imread(r'C:\Users\zyy\Downloads\pydata-book-master\ch03\stinkbug.png')figure(figsize=(4,4))plt.imshow(img)
# Out:
# &lt;matplotlib.image.AxesImage at 0x57b6610&gt;
